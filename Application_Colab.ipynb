# %% [markdown]
# <a href="https://colab.research.google.com/github/LuchoGabba/qibo/blob/main/Application_Colab.ipynb"> <img src='https://colab.research.google.com/assets/colab-badge.svg' /> </a>
# <div align="center"> Recordá abrir en una nueva pestaña </div>

# %% [markdown]
# # Talk
#
# https://www.youtube.com/watch?v=Aoc4nLmplTE

# %%
# !nvidia-smi
# Out:
# Sun Oct 29 01:01:31 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 451.83       Driver Version: 451.83       CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce MX450      WDDM  | 00000000:2E:00.0 Off |                  N/A |
# | N/A   59C    P8    N/A /  N/A |    119MiB /  2048MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
Circuit characterization:
Circuit depth = 17
Total number of gates = 78
Number of qubits = 6
Most common gates:
ry: 54
cz: 24
# Out:
# 72

# %%
24*24
# Out:
# 576

# %%
import matplotlib.pyplot as plt

nqubits = 6
nlayers  = 4

initial_parameters = np.random.uniform(0, 2*np.pi,
                                        2*nqubits*nlayers + nqubits)

# Visualization
plt.figure(figsize=(10,5))
plt.plot(initial_parameters, marker='o', linestyle='-')
plt.xlabel('Parameter Index')
plt.ylabel('Parameter Value')
plt.title('Initial Parameters for VQE Ansatz')
plt.ylim([0, 2*np.pi])
plt.grid(True)
plt.show()
